# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
tokenizer = Tokenizer(BPE())

# %%
tokenizer.pre_tokenizer = Whitespace()

# %%
trainer = BpeTrainer(special_tokens=[])

# %%
tokenizer.train(files=["data/tinyshakespeare.txt"], trainer=trainer)

# %%
tokenizer.get_vocab()
# Out:
# {'Tri': 4152,
#  'enes': 2860,
#  'divor': 5505,
#  'gratulate': 10553,
#  'Honourable': 17091,
#  'Discharge': 15312,
#  'pic': 3565,
#  'gree': 3737,
#  'Socrates': 18016,
#  'subsid': 14111,
#  'Aiming': 17067,
#  'Esteem': 17500,
#  'walking': 8415,
#  'husbandry': 9810,
#  'fourth': 8147,
#  'durance': 10315,
#  'ENER': 12525,
#  'tance': 6440,
#  'psalteries': 18047,
#  'MONTAGUE': 2191,
#  'stacles': 9028,
#  'wounded': 3493,
#  'instigation': 10487,
#  'Mo': 7304,
#  'Ava': 11072,
#  'inquisition': 17767,
#  'downfall': 5995,
#  'praises': 5033,
#  'spied': 13351,
#  'ensign': 8999,
#  'Disbursed': 15323,
#  'owed': 9102,
#  'ace': 599,
#  'PHILIP': 17105,
#  'digest': 6669,
#  'recourse': 12233,
#  'aring': 2679,
#  'hai': 12207,
#  'pe': 149,
#  'woodman': 15666,
#  'captain': 3913,
#  'Thi': 1153,
#  'arrives': 15443,
#  'onely': 9261,
#  'bone': 6360,
#  'villages': 14382,
#  'afterward': 6033,
#  'almost': 2179,
#  'sake': 1654,
#  'meets': 9870,
#  'cries': 3325,
# ...

# %%
output = tokenizer.encode("Your belly's answer? What!")

# %%
output.attention_mask
# Out:
# [1, 1, 1, 1, 1, 1, 1, 1]

# %%
output.ids
# Out:
# [510, 3165, 2, 54, 1018, 9, 228, 0]

# %%
output.tokens
# Out:
# ['Your', 'belly', "'", 's', 'answer', '?', 'What', '!']

# %%
tokenizer.save("./data/tokenizer.json")

# %%
pretrained = Tokenizer.from_file("./data/tokenizer.json")

# %%
pretrained.encode("Your belly's answer? What!").tokens
# Out:
# ['Your', 'belly', "'", 's', 'answer', '?', 'What', '!']
